# %%
# integrate luminosity functions out to M_UV = -10 equivalent maybe?
# convert from luminosity to sSFR with a better function than the one I have/ the one in Kennicutt & Evans 2012
# Then you have three points for Cosmic sSFR?

# %%
import numpy as np
import emcee
import matplotlib.pyplot as plt
# %matplotlib inline

Data = np.genfromtxt('schechterfits.csv', delimiter = ',')
red = Data[:,0]
rederr = Data[:,1]
mstar = Data[:,2]
mstarerr = Data[:,3]
alpha = Data[:,4]
alphaerr = Data[:,5]
pstar = Data[:,6]
pstarerr = Data[:,7]

# %%
mags = np.linspace(-10, -30, 1500)
lums = (10**(-.4*(mags + 48.6)))*(4*np.pi*3.086e19**2)*(3e8/1.6e-5) # turning everything into ergs/s

lstar = 10**(-.4*(mstar + 48.6))*(4*np.pi*3.086e19**2)*(3e8/1.6e-5) 
lstarerr = 10**(-.4*(mstar - mstarerr + 48.6))*(4*np.pi*3.086e19**2)*(3e8/1.6e-5) - lstar

fits = []
errfit = []

for i in range(len(Data[:,0])):
    a = pstar[i]*(lums/lstar[i])**(alpha[i])*np.exp(-lums/lstar[i])
    b = (pstar[i]-pstarerr[i])*(lums/(lstar[i]+lstarerr[i]))**(alpha[i]+alphaerr[i])*np.exp(-lums/(lstar[i]+lstarerr[i]))
    fits.append(a)
    errfit.append(b)

fits = np.asarray(fits)
errfit = np.asarray(errfit)

Rsums = np.zeros([len(fits[:,0])])
Rsumserr = np.zeros([len(fits[:,0])])


for i in range(len(lums)):
    for j in range(len(fits[:,0])):
        if i < np.max(range(len(lums))):
            Rsums[j] += fits[j,i]*np.abs(lums[i]-lums[i+1]) # this is the luminosity density
            Rsumserr[j] += errfit[j,i]*np.abs(lums[i]-lums[i+1]) # this is something like the error

# %%
plt.semilogy(red, Rsums, '.')
plt.semilogy(red, Rsumserr, '.')

# %%
# from Kennicutt and Evans 2012

SFR = 10**(np.log10(Rsums) - 43.35)
SFRerr = 10**(np.log10(Rsumserr) - 43.35)
SFRerr[5] = 1e-2
SFRerr[8] = 1e-4
# Out:
# /home/max/anaconda2/envs/moresnakes/lib/python3.5/site-packages/ipykernel/__main__.py:4: RuntimeWarning: invalid value encountered in log10

# %%
plt.figure(figsize=(10,10))
plt.semilogy(red, SFR, '.')
plt.semilogy(red, SFRerr, '.', alpha = .5)
print(SFRerr)
# I couldn't get plt.errorbar to work (I never do for some reason) so the errors are printed in light green
# Out:
# [  4.82623008e-05   1.05199241e-01   1.38168746e-01   1.27601109e-01
#    6.98073339e-02              nan   3.08773543e-04   5.97861141e-04
#               nan   2.68870718e-04   3.02866730e-04   3.47846803e-04
#    4.66689127e-04   2.83957682e-03   8.94805402e-03   2.67729021e-02]
# /home/max/anaconda2/envs/moresnakes/lib/python3.5/site-packages/matplotlib/scale.py:93: RuntimeWarning: invalid value encountered in less_equal
#   mask = a <= 0.0

# %% [markdown]
# I do not find a turn-off in the data like Madau does in Figure 9 with the Bouwens 2012 data, which is odd. I imagine they are using a more sophisticated conversion technique from UV to SFR than I am.

# %%
# converting back into total magnitudes

totmags = -2.5*np.log10((10**(np.log10(SFR) +43.35 - np.log10(3e8/1.6e-5)))/(4*np.pi*3.086e19**2))-48.6
totmagserr = np.abs(-2.5*np.log10((10**(np.log10(SFR+SFRerr) +43.35 - np.log10(3e8/1.6e-5)))/(4*np.pi*3.086e19**2))-48.6 - totmags)
totmagserr[5] = 1.
totmagserr[8] = .61
print(totmags)
# Out:
# [-15.24875512 -21.5705526  -22.08817316 -22.69404733 -22.69915398
#  -16.46739188 -15.05652855 -15.84124329 -15.41429273 -14.97115905
#  -15.15629611 -15.5050107  -16.41110048 -18.57245345 -20.18874741
#  -21.56176722]

# %%
def model(theta, z):
    sc = theta[0]*(1+z)**(theta[1])/(1+((1+z)/theta[2])**(theta[3]))
    return sc

def logL(theta, z, N, err):
    return -.5* np.sum((N - model(theta, z))**2./err**2.)

def lnprior(theta):
    if theta[0] < 1e-5: 
        return -np.inf    
    elif theta[0] > .002: # this came from many previous runs that exhibited a low-end peak
        return -np.inf
    if theta[1] < .00001: 
        return -np.inf
    elif theta[1] > 10.:
        return -np.inf
    if theta[2] < 0:
        return -np.inf    
    elif theta[2] > 10.:
        return -np.inf
    if theta[3] < 0:
        return -np.inf    
    elif theta[3] > 50.:
        return -np.inf    
    else:
        return 0

def lnprob(theta, L, N, err):
    if lnprior(theta) == -np.inf:
        return -np.inf
    else:
        return logL(theta, L, N, err) + lnprior(theta)
    
ndim, nwalkers = 4, 100
pos = [[1e-3, 1, 1, 1]*np.random.randn(ndim) for i in range(nwalkers)]


sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args = [red, totmags, totmagserr])
sampler.run_mcmc(pos, 20000)
# Out:
# /home/max/anaconda2/envs/moresnakes/lib/python3.5/site-packages/emcee/ensemble.py:335: RuntimeWarning: invalid value encountered in subtract
#   lnpdiff = (self.dim - 1.) * np.log(zz) + newlnprob - lnprob0
# /home/max/anaconda2/envs/moresnakes/lib/python3.5/site-packages/emcee/ensemble.py:336: RuntimeWarning: invalid value encountered in greater
#   accept = (lnpdiff > np.log(self._random.rand(len(lnpdiff))))
# (array([[  6.04940514e-04,   4.12499742e+00,   6.36813146e-01,
#            4.56276613e+01],
#         [  7.06825410e-04,   1.93456080e+00,   5.53896131e-01,
#            3.39347423e+01],
#         [  2.27086366e-04,   3.77375351e+00,   1.77614311e+00,
#            3.48466322e+01],
#         [  1.44285315e-03,   1.96242305e+00,   6.39670463e-01,
#            3.12280421e+01],
#         [  4.66127011e-05,   6.13276634e-01,   6.04197802e-01,
#            3.36821402e+01],
#         [  1.55285477e-03,   7.28669325e+00,   3.01649917e-01,
#            2.01424954e+01],
# ...

# %%
plt.figure(figsize = (10,10))
[plt.plot(sampler.lnprobability[i,300:]) for i in range(100)]
plt.xlabel('step number', fontsize = 20)
plt.ylabel('lnP', fontsize = 20)

# %%
import corner

samples = sampler.chain[:,300:,:].reshape((-1, ndim))
corner.corner(samples, labels=['A', 'alpha', 'B', 'gamma'], fontsize = 20, show_titles = True, quantiles=[0.16, 0.5, 0.84])

# %% [markdown]
# I have no idea why I'm getting such bad fits for everything but B. Hm! There is some evidence I have that A and alpha are peaking, but it is hard to investigate those narrow peaks when gamma is all over the place. Once again I think this might be going to the issue of some error I have in putting in the Bouwens Schechter fit values.

# %%
plt.plot(red, totmags, '.')
plt.plot(red, totmags-totmagserr, '.')

# %% [markdown]
# Oh no I see what's happening! I don't need to convert to magnitudes as it is in Finkelstein, just as it is in Madau.

# %%
def model(theta, z):
    sc = theta[0]*(1+z)**(theta[1])/(1+((1+z)/theta[2])**(theta[3]))
    return sc

def logL(theta, z, N, err):
    return -.5* np.sum((N - model(theta, z))**2./err**2.)

def lnprior(theta):
    if theta[0] < 1e-5: 
        return -np.inf    
    elif theta[0] > .1:
        return -np.inf
    if theta[1] < .00001: 
        return -np.inf
    elif theta[1] > 10.:
        return -np.inf
    if theta[2] < 0:
        return -np.inf    
    elif theta[2] > 10.:
        return -np.inf
    if theta[3] < 0:
        return -np.inf    
    elif theta[3] > 50.:
        return -np.inf    
    else:
        return 0

def lnprob(theta, L, N, err):
    if lnprior(theta) == -np.inf:
        return -np.inf
    else:
        return logL(theta, L, N, err) + lnprior(theta)
    
ndim, nwalkers = 4, 100
pos = [[1e-1, 1, 1, 1]*np.random.randn(ndim) for i in range(nwalkers)]


sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args = [red, SFR, SFRerr])
sampler.run_mcmc(pos, 50000)
# Out:
# /home/max/anaconda2/envs/moresnakes/lib/python3.5/site-packages/emcee/ensemble.py:335: RuntimeWarning: invalid value encountered in subtract
#   lnpdiff = (self.dim - 1.) * np.log(zz) + newlnprob - lnprob0
# /home/max/anaconda2/envs/moresnakes/lib/python3.5/site-packages/emcee/ensemble.py:336: RuntimeWarning: invalid value encountered in greater
#   accept = (lnpdiff > np.log(self._random.rand(len(lnpdiff))))
# (array([[  2.72756091e-05,   4.98813467e+00,   7.82114242e+00,
#            4.96930428e+01],
#         [  9.62019068e-02,   7.69097277e+00,   4.10513504e-01,
#            6.35987879e+00],
#         [ -1.40098767e-01,  -4.74518168e-01,   7.16364741e-01,
#            6.56665666e-01],
#         [  5.84723134e-05,   4.40051847e+00,   7.95041557e+00,
#            3.98036626e+01],
#         [ -1.36996778e-01,   5.35277124e-01,  -7.40961578e-01,
#            1.33566047e+00],
#         [  2.52895499e-01,   1.23830353e-01,  -4.93906550e-02,
#            3.04827878e-01],
# ...

# %%
plt.figure(figsize = (10,10))
[plt.plot(sampler.lnprobability[i,5000:]) for i in range(100)]
plt.xlabel('step number', fontsize = 20)
plt.ylabel('lnP', fontsize = 20)

# %%
import corner

samples = sampler.chain[:,37000:,:].reshape((-1, ndim))
corner.corner(samples, labels=['A', 'alpha', 'B', 'gamma'], fontsize = 20, show_titles = True, quantiles=[0.16, 0.5, 0.84])

# %%
print(np.mean(sampler.chain[:,37000:,0]))
print(np.mean(sampler.chain[:,37000:,1]))
print(np.mean(sampler.chain[:,37000:,2]))
print(np.mean(sampler.chain[:,37000:,3]))
# Out:
# 0.00221761449565
# 3.49505820796
# 2.38436106607
# 12.730559471

# %% [markdown]
# This bimodal distribution in some of the parameters looks intractable to me right now. The average value of gamma is close to what Madau found, though the uncertainties are humongous here. Oddly enough, neither of the A or B peaks are near the Madau value.

# %%
thetaavg = [.0022, 3.50, 2.38, 12.7]


plt.semilogy(red, SFR, '.')
plt.semilogy(red, SFRerr, '.')
plt.semilogy(red, thetaavg[0]*(1+red)**(thetaavg[1])/(1+((1+red)/thetaavg[2])**(thetaavg[3])), 'o')

# %% [markdown]
# Given the errors involved, this isn't such a bad fit on the high end. They are pretty bad on the low z end though. What to do????
